# %% [markdown]
# <a href="https://colab.research.google.com/github/trongthuan205/DS102.K21/blob/master/02_MultipleLinearRegression_Rent_Bike.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from math import sqrt

# %%
sum_r2 = 0
sum_RSME = 0

# %%
! git clone https://github.com/trongthuan205/DS102.K21 DS102.K21
# Out:
# Cloning into 'DS102.K21'...
# remote: Enumerating objects: 169, done.
# remote: Counting objects: 100% (169/169), done.
# remote: Compressing objects: 100% (169/169), done.
# remote: Total 302 (delta 96), reused 0 (delta 0), pack-reused 133
# Receiving objects: 100% (302/302), 2.65 MiB | 2.37 MiB/s, done.
# Resolving deltas: 100% (171/171), done.

# %%
for i in range(1,6):
    X_train = pd.read_csv('DS102.K21/Bike_Train0'+str(i)+'.csv').iloc[:,3:-2].values
    y_train = pd.read_csv('DS102.K21/Bike_Train0'+str(i)+'.csv').iloc[:,-2].values
    X_test = pd.read_csv('DS102.K21/Bike_Test0'+str(i)+'.csv').iloc[:,3:-2].values
    y_test = pd.read_csv('DS102.K21/Bike_Test0'+str(i)+'.csv').iloc[:,-2].values
    lm = LinearRegression()
    lm = lm.fit(X_train, y_train)
    y_pred_train = lm.predict(X_train)
    y_pred_test = lm.predict(X_test)
    r2 = r2_score(y_test, y_pred_test)
    sum_r2 += r2
    RSME = sqrt(mean_squared_error(y_test, y_pred_test))
    sum_RSME += RSME
    print('R2_%s:' % i, r2)
    print('RMSE_%s:' % i, RSME)
# Out:
# R2_1: 0.5896499379393549
# RMSE_1: 611.0178834975131
# R2_2: 0.5896499379393549
# RMSE_2: 611.0178834975131
# R2_3: 0.13169776260566124
# RMSE_3: 617.3366951876989
# R2_4: 0.5927699330088481
# RMSE_4: 576.701746599156
# R2_5: 0.4508091072338227
# RMSE_5: 723.665957495902

# %%
print('Average of R2: ', sum_r2/5)
print('Average of RMSE: ', sum_RSME/5)
# Out:
# Average of R2:  0.4709153357454084
# Average of RMSE:  627.9480332555565
