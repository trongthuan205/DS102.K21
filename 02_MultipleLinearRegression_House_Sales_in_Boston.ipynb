# %% [markdown]
# <a href="https://colab.research.google.com/github/trongthuan205/DS102.K21/blob/master/02_MultipleLinearRegression_House_Sales_in_Boston.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 0 . Import libaray

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from math import sqrt
import sklearn.metrics as metrics
from sklearn.metrics import r2_score

# %% [markdown]
# # 1 . Load data

# %%
! git clone https://github.com/trongthuan205/DS102.K21 DS102.K21
# Out:
# Cloning into 'DS102.K21'...
# remote: Enumerating objects: 305, done.
# remote: Total 305 (delta 0), reused 0 (delta 0), pack-reused 305
# Receiving objects: 100% (305/305), 2.64 MiB | 2.00 MiB/s, done.
# Resolving deltas: 100% (175/175), done.

# %%
data_train = pd.read_csv('DS102.K21/BostonTrain.csv')
data_test = pd.read_csv('DS102.K21/BostonTest.csv')

# %% [markdown]
# # 2 . Split data

# %%
X_train = data_train.iloc[:,1:-1].values
y_train = data_train.iloc[:,-1].values
X_test = data_test.iloc[:,1:-1].values
y_test = data_test.iloc[:,-1].values

# %% [markdown]
# # 3 . Buil model

# %%
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
y_pred = lin_reg.predict(X_train)

# %% [markdown]
# # 4 . Compare

# %%
def compare(i_example):
    X = X_test[i_example:i_example + 1]
    y = y_test[i_example]
    y_pred = lin_reg.predict(X)
    print(y,y_pred)

# %%
for i in range(len(X_test)):
    compare(i)
# Out:
# 5.6 [14.56745501]
# 7.2 [19.91632628]
# 12.1 [20.14810352]
# 8.3 [15.40504793]
# 8.5 [12.04976541]
# 5.0 [15.52034637]
# 11.9 [8.91418981]
# 27.9 [22.05913302]
# 17.2 [14.66541409]
# 27.5 [24.33848478]
# 15.0 [24.98152081]
# 17.2 [22.68535893]
# 17.9 [5.70902364]
# 16.3 [16.05993111]
# 7.0 [2.14939673]
# 7.2 [15.64375565]
# 7.5 [19.09003916]
# 10.4 [11.79927477]
# 8.8 [18.26422801]
# 8.4 [20.37723105]
# 16.7 [22.61982905]
# 14.2 [20.29269315]
# 20.8 [20.90683104]
# 13.4 [18.00623515]
# 11.7 [19.26815054]
# 8.3 [15.68262221]
# 10.2 [21.36561063]
# 10.9 [22.66756245]
# 11.0 [18.46680508]
# 9.5 [17.98999374]
# 14.5 [22.67477051]
# 14.1 [23.78142011]
# 16.1 [25.95600286]
# 14.3 [21.7140953]
# 11.7 [21.40735676]
# 13.4 [18.48727695]
# 9.6 [20.90369508]
# 8.7 [14.85411472]
# 8.4 [9.51287842]
# 12.8 [14.10573883]
# 10.5 [15.37072273]
# 17.1 [19.37681282]
# 18.4 [20.25282765]
# 15.4 [20.25105418]
# 10.8 [14.73291352]
# 11.8 [17.53218742]
# 14.9 [20.11612465]
# 12.6 [20.23376098]
# ...

# %% [markdown]
# # 5 . Evaluate

# %%
y_test_pred = lin_reg.predict(X_test)

# %%
print('RMS=', sqrt(mean_squared_error(y_test, y_test_pred)))
print('MSE= ', mean_squared_error(y_test, y_test_pred))
print('MAE= ', metrics.mean_absolute_error(y_test, y_test_pred))
print('R2= ', r2_score(y_test, y_test_pred))
# Out:
# RMS= 5.986804304791552
# MSE=  35.84182578387066
# MAE=  4.927930263256073
# R2=  -0.26840776319974213
