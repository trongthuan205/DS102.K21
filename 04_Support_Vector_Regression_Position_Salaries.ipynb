# %% [markdown]
# <a href="https://colab.research.google.com/github/trongthuan205/DS102.K21/blob/master/04_Support_Vector_Regression_Position_Salaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 0 . Load library

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
import matplotlib.pyplot as plt

# %% [markdown]
# # 1 . Load data

# %%
! git clone https://github.com/trongthuan205/DS102.K21 DS102.K21

# %%
position_salaries = pd.read_csv('DS102.K21/Position_Salaries.csv')

# %% [markdown]
# 2 . Normalize data

# %% [markdown]
# 3 . Build model

# %% [markdown]
# 4 . Redifination

# %% [markdown]
# 5 . Visualize
