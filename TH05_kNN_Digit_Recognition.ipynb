# %% [markdown]
# <a href="https://colab.research.google.com/github/trongthuan205/DS102.K21/blob/master/TH05_kNN_Digit_Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 0 . Import library

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
import matplotlib.pyplot as plt
import matplotlib
from sklearn.metrics import accuracy_score
import pandas as pd
from collections import Counter
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

# %% [markdown]
# # 1 . Load data

# %%
data = keras.datasets.mnist

# %%
(X_trainFull, y_trainFull), (X_testFull, y_testFull) = data.load_data()

# %%
print(X_trainFull.shape[0], 'train samples')

# %%
print(X_testFull.shape[0], 'test samples')

# %% [markdown]
# # 2 . Split data

# %%
X_train = X_trainFull[0:600]

# %%
X_train.shape

# %%
y_train = y_trainFull[0:600]

# %%
y_train.shape

# %%
X_test = X_testFull[0:100]

# %%
X_test.shape

# %%
y_test = y_testFull[0:100]

# %%
y_test.shape

# %% [markdown]
# # 3 . Statistic data

# %%
Counter(np.array(y_trainFull))

# %%
Counter(np.array(y_testFull))

# %% [markdown]
# # 4 . Visualize data

# %%
#Visulize random digit
digit = X_train[0,:]
plt.imshow(digit, cmap = matplotlib.cm.get_cmap('gist_gray'))

# %%
#Visualize top 9 digit
plt.figure(figsize = (15, 15))
for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.imshow(X_train[i], cmap = matplotlib.cm.get_cmap('gist_gray'))

# %%
#Visualize top 9 digit in class 7
index = np.where(y_train == 7)[0][:9]
plt.figure(figsize = (10,10))
for i, j in enumerate(index):
    plt.subplot(3, 3, i+1)
    plt.imshow(X_train[j], cmap = matplotlib.cm.get_cmap('gist_gray'))

# %% [markdown]
# # 5 . kNN Classifier

# %% [markdown]
# Normalize data

# %%
X_train, X_test = X_train.reshape(X_train.shape[0], -1), X_test.reshape(X_test.shape[0], -1)

# %%
X_train.shape

# %%
X_test.shape

# %%
y_train, y_test = y_train.reshape(-1,1), y_test.reshape(-1, 1)

# %%
y_train.shape

# %%
y_test.shape

# %%
SC = StandardScaler()
X_train = SC.fit_transform(X_train)

# %% [markdown]
# Build model and Evaluate

# %%
acc = {}
for k in range(1, 8, 2):
    model = KNeighborsClassifier(n_neighbors = k, metric = 'euclidean')
    model.fit(X_train, y_train)
    y_pred_train = model.predict(X_train)
    acc[k] = accuracy_score(y_train, y_pred_train)
    plot_confusion_matrix(model, X_train, y_train)
print('Accuracy score: ', acc)

# %%
acc = {}
for k in range(1, 8, 2):
    model = KNeighborsClassifier(n_neighbors = k, metric = 'minkowski')
    model.fit(X_train, y_train)
    y_pred_train = model.predict(X_train)
    acc[k] = accuracy_score(y_train, y_pred_train)
    plot_confusion_matrix(model, X_train, y_train)
print('Accuracy score: ', acc)

# %%
acc = {}
for k in range(1, 8, 2):
    model = KNeighborsClassifier(n_neighbors = k, metric = 'cosine')
    model.fit(X_train, y_train)
    y_pred_train = model.predict(X_train)
    acc[k] = accuracy_score(y_train, y_pred_train)
    plot_confusion_matrix(model, X_train, y_train)
print('Accuracy score: ', acc)
